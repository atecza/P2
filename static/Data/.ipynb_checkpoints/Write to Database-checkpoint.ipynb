# %%
from config import key
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, join
import psycopg2

#make sure you have your own config on your computer in the SQL folder

# %%
from flask import Flask, jsonify
import datetime as dt

# %%
CData = pd.read_csv('CountryData_SQL.csv')
EData = pd.read_csv('EnvData_SQL.csv')
SData = pd.read_csv('States_SQL.csv')
EmData = pd.read_csv('Emissions_SQL.csv')

# %%
SData.head()
# Out:
#        Country
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3       Angola
# 4    Argentina

# %%
pg_user = 'postgres'
pg_pwd = key
pg_port = "5432"

#remember to make this db in pgAdmin before
# run Final_Query.sql in pgAdmin to create the tables

database = 'Project2'
url = f"postgresql://{pg_user}:{pg_pwd}@localhost:{pg_port}/{database}"

# %%
#Create the engine
engine = create_engine(f'{url}')

# %% [markdown]
# ## Write Data to SQL

# %%
SData.to_sql('states', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %%
CData.to_sql('countrydata', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %%
EData.to_sql('envdata', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %%
len(EmData)
# Out:
# 2380

# %%
EmData = EmData.dropna()

# %%
EmData.to_sql('emissionsdata', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %% [markdown]
# ## Test SQL Code for app.py

# %%
Base = automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['states', 'envdata', 'countrydata', 'emissionsdata']

# %%
EnvironmentData = Base.classes.envdata
CountryData = Base.classes.countrydata
EmissionsData = Base.classes.emissionsdata

# %%
EnvironmentData
# Out:
# sqlalchemy.ext.automap.envdata

# %%
session = Session(engine)

# %% [markdown]
# #Extra Code
# EnvData = engine.execute('SELECT * FROM env LIMIT 5').fetchall()
# CountryData = engine.execute('SELECT * FROM countrydata LIMIT 5').fetchall()
# EnvData[0][2]

# %% [markdown]
# #Join not working
# EnvData = session.query(EnvData).join(CountryData, CountryData.Country == EnvData.Country).all()

# %%
EData = session.query(EnvironmentData).all()
Countries = []
HDI = []
FC = []
FG = []
FF = []
FCar = []
FFish = []
FT = []
LU = []
ECO2 = []
DQ = []




for x in EData:
    Countries.append(x.Country)
    HDI.append(x.HDI)
    FC.append(x.Footprint_Crop)
    FG.append(x.Footprint_Graze)
    FF.append(x.Footprint_Forest)
    FCar.append(x.Footprint_Carbon)
    FFish.append(x.Footprint_Fish)
    FT.append(x.Footprint_Total)
    LU.append(x.Land_Urban)
    ECO2.append(x.Emissions_CO2)
    DQ.append(x.Data_Quality)

# %%
CData = session.query(CountryData).all()

SurArea = []
Pop = []
PopD = []
PopGr = []
PopUrb = []
GDP = []
GDPGrowth = []
EconAg = []
EconInd = []
EconServ = []
GovEd = []
WP = []

for x in CData:
    SurArea.append(x.Surface_Area)
    Pop.append(x.Population)
    PopD.append(x.PopDensity)
    PopGr.append(x.PopGrowth)
    PopUrb.append(x.PopUrban)
    EconAg.append(x.EconAg)
    EconInd.append(x.EconInd)
    EconServ.append(x.EconService)
    GovEd.append(x.Gov_Education)
    WP.append(x.Women_Parliment)

# %%
full_data = {
    "Country":Countries,
    "HDI":HDI,
    "Footprint_Crop":FC,
    "Footprint_Graze":FG,
    "Footprint_Forest":FF,
    "Footprint_Carbon":FCar,
    "Footprint_Fish":FF,
    "Footprint_Total":FT,
    "Land_Urban":LU,
    "Emissions_CO2":ECO2,
    "Data_Quality":DQ,
    "Area":SurArea,
    "Population":Pop,
    "PopDensity":PopD,
    "PopGrowth":PopGr,
    "PopUrban":PopUrb,
    "EconAg":EconAg,
    "EconInd":EconInd,
    "EconServ":EconServ,
    "GovEducation":GovEd,
    "Women_Parliment":WP
    
}

# %%
EnvData = {"data":full_data}

# %% [markdown]
# ## Try a different format

# %%
EData = session.query(EnvironmentData).all()
myData = []

for x in EData:
    
    fullEdata = {}
    
    fullEdata = {
        "Country": x.Country,
        "HDI":x.HDI,
        "Footprint_Crop":x.Footprint_Crop,
        "Footprint_Graze":x.Footprint_Graze,
        "Footprint_Forest":x.Footprint_Forest,
        "Footprint_Carbon":x.Footprint_Carbon,
        "Footprint_Fish":x.Footprint_Fish,
        "Footprint_Total":x.Footprint_Total,
        "Land_Urban":x.Land_Urban,
        "Emission_CO2":x.Emissions_CO2,
        "BioCap":x.Biocapacity_Total,
        "BioCap_RD":x.BioCap_RD,
        "Data_Quality":x.Data_Quality
    }
    
    myData.append(fullEdata)

# %%
myData
# Out:
# [{'Country': 'Afghanistan',
#   'HDI': 0.46,
#   'Footprint_Crop': 0.3,
#   'Footprint_Graze': 0.2,
#   'Footprint_Forest': 0.08,
#   'Footprint_Carbon': 0.18,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 0.79,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 63,
#   'BioCap': 0.5,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Albania',
#   'HDI': 0.73,
#   'Footprint_Crop': 0.78,
#   'Footprint_Graze': 0.22,
#   'Footprint_Forest': 0.25,
#   'Footprint_Carbon': 0.87,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 2.21,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 84,
#   'BioCap': 1.18,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Algeria',
#   'HDI': 0.73,
#   'Footprint_Crop': 0.6,
#   'Footprint_Graze': 0.16,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 1.14,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 2.12,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 5900,
#   'BioCap': 0.59,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Angola',
#   'HDI': 0.52,
#   'Footprint_Crop': 0.33,
#   'Footprint_Graze': 0.15,
#   'Footprint_Forest': 0.12,
#   'Footprint_Carbon': 0.2,
#   'Footprint_Fish': 0.09,
#   'Footprint_Total': 0.93,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 3902,
#   'BioCap': 2.55,
#   'BioCap_RD': 2,
#   'Data_Quality': 6},
#  {'Country': 'Argentina',
#   'HDI': 0.83,
#   'Footprint_Crop': 0.78,
#   'Footprint_Graze': 0.79,
#   'Footprint_Forest': 0.29,
#   'Footprint_Carbon': 1.08,
#   'Footprint_Fish': 0.1,
#   'Footprint_Total': 3.14,
#   'Land_Urban': 0.1,
#   'Emission_CO2': 3167,
#   'BioCap': 6.92,
#   'BioCap_RD': 4,
#   'Data_Quality': 6},
#  {'Country': 'Armenia',
#   'HDI': 0.73,
#   'Footprint_Crop': 0.74,
#   'Footprint_Graze': 0.18,
#   'Footprint_Forest': 0.34,
#   'Footprint_Carbon': 0.89,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 2.23,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 48,
#   'BioCap': 0.89,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Australia',
#   'HDI': 0.93,
#   'Footprint_Crop': 2.68,
#   'Footprint_Graze': 0.63,
#   'Footprint_Forest': 0.89,
#   'Footprint_Carbon': 4.85,
#   'Footprint_Fish': 0.11,
#   'Footprint_Total': 9.31,
#   'Land_Urban': 0.14,
#   'Emission_CO2': 15282,
#   'BioCap': 16.57,
#   'BioCap_RD': 7,
#   'Data_Quality': 5},
#  {'Country': 'Austria',
#   'HDI': 0.88,
#   'Footprint_Crop': 0.82,
#   'Footprint_Graze': 0.27,
#   'Footprint_Forest': 0.63,
#   'Footprint_Carbon': 4.14,
#   'Footprint_Fish': 0.06,
#   'Footprint_Total': 6.06,
#   'Land_Urban': 0.15,
#   'Emission_CO2': 505,
#   'BioCap': 3.07,
#   'BioCap_RD': -3,
#   'Data_Quality': 5},
#  {'Country': 'Azerbaijan',
#   'HDI': 0.75,
#   'Footprint_Crop': 0.66,
#   'Footprint_Graze': 0.22,
#   'Footprint_Forest': 0.11,
#   'Footprint_Carbon': 1.25,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 2.31,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 2459,
#   'BioCap': 0.85,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Bahamas',
#   'HDI': 0.78,
#   'Footprint_Crop': 0.97,
#   'Footprint_Graze': 1.05,
#   'Footprint_Forest': 0.19,
#   'Footprint_Carbon': 4.46,
#   'Footprint_Fish': 0.14,
#   'Footprint_Total': 6.84,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 0,
#   'BioCap': 9.55,
#   'BioCap_RD': 3,
#   'Data_Quality': 3},
#  {'Country': 'Bahrain',
#   'HDI': 0.82,
#   'Footprint_Crop': 0.52,
#   'Footprint_Graze': 0.45,
#   'Footprint_Forest': 0.16,
#   'Footprint_Carbon': 6.19,
#   'Footprint_Fish': 0.07,
#   'Footprint_Total': 7.49,
#   'Land_Urban': 0.1,
#   'Emission_CO2': 961,
#   'BioCap': 0.58,
#   'BioCap_RD': -7,
#   'Data_Quality': 3},
#  {'Country': 'Bangladesh',
#   'HDI': 0.56,
#   'Footprint_Crop': 0.29,
#   'Footprint_Graze': 0.0,
#   'Footprint_Forest': 0.08,
#   'Footprint_Carbon': 0.26,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 0.72,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 1438,
#   'BioCap': 0.38,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Barbados',
#   'HDI': 0.79,
#   'Footprint_Crop': 0.56,
#   'Footprint_Graze': 0.24,
#   'Footprint_Forest': 0.14,
#   'Footprint_Carbon': 3.28,
#   'Footprint_Fish': 0.22,
#   'Footprint_Total': 4.48,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 2,
#   'BioCap': 0.19,
#   'BioCap_RD': -4,
#   'Data_Quality': 5},
#  {'Country': 'Belarus',
#   'HDI': 0.8,
#   'Footprint_Crop': 1.32,
#   'Footprint_Graze': 0.12,
#   'Footprint_Forest': 0.91,
#   'Footprint_Carbon': 2.57,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 5.09,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 155,
#   'BioCap': 3.64,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Belgium',
#   'HDI': 0.89,
#   'Footprint_Crop': 1.15,
#   'Footprint_Graze': 0.48,
#   'Footprint_Forest': 0.99,
#   'Footprint_Carbon': 4.43,
#   'Footprint_Fish': 0.12,
#   'Footprint_Total': 7.44,
#   'Land_Urban': 0.27,
#   'Emission_CO2': 520,
#   'BioCap': 1.19,
#   'BioCap_RD': -6,
#   'Data_Quality': 6},
#  {'Country': 'Benin',
#   'HDI': 0.48,
#   'Footprint_Crop': 0.49,
#   'Footprint_Graze': 0.04,
#   'Footprint_Forest': 0.26,
#   'Footprint_Carbon': 0.51,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 1.41,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 96,
#   'BioCap': 0.88,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Bhutan',
#   'HDI': 0.59,
#   'Footprint_Crop': 0.5,
#   'Footprint_Graze': 0.42,
#   'Footprint_Forest': 3.03,
#   'Footprint_Carbon': 0.63,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 4.84,
#   'Land_Urban': 0.25,
#   'Emission_CO2': 75,
#   'BioCap': 5.27,
#   'BioCap_RD': 0,
#   'Data_Quality': 3},
#  {'Country': 'Bosnia and Herzegovina',
#   'HDI': 0.73,
#   'Footprint_Crop': 0.63,
#   'Footprint_Graze': 0.27,
#   'Footprint_Forest': 0.44,
#   'Footprint_Carbon': 1.74,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 3.12,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 252,
#   'BioCap': 1.63,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Botswana',
#   'HDI': 0.69,
#   'Footprint_Crop': 0.3,
#   'Footprint_Graze': 0.89,
#   'Footprint_Forest': 0.24,
#   'Footprint_Carbon': 2.36,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 3.83,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 47,
#   'BioCap': 3.47,
#   'BioCap_RD': 0,
#   'Data_Quality': 3},
#  {'Country': 'Brazil',
#   'HDI': 0.75,
#   'Footprint_Crop': 0.62,
#   'Footprint_Graze': 0.85,
#   'Footprint_Forest': 0.6,
#   'Footprint_Carbon': 0.91,
#   'Footprint_Fish': 0.04,
#   'Footprint_Total': 3.11,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 10948,
#   'BioCap': 9.08,
#   'BioCap_RD': 6,
#   'Data_Quality': 5},
#  {'Country': 'Brunei Darussalam',
#   'HDI': 0.85,
#   'Footprint_Crop': 0.31,
#   'Footprint_Graze': 0.13,
#   'Footprint_Forest': 0.26,
#   'Footprint_Carbon': 3.24,
#   'Footprint_Fish': 0.09,
#   'Footprint_Total': 4.06,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 679,
#   'BioCap': 2.87,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Bulgaria',
#   'HDI': 0.78,
#   'Footprint_Crop': 0.6,
#   'Footprint_Graze': 0.13,
#   'Footprint_Forest': 0.35,
#   'Footprint_Carbon': 2.08,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 3.32,
#   'Land_Urban': 0.13,
#   'Emission_CO2': 474,
#   'BioCap': 2.86,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Burkina Faso',
#   'HDI': 0.39,
#   'Footprint_Crop': 0.47,
#   'Footprint_Graze': 0.17,
#   'Footprint_Forest': 0.36,
#   'Footprint_Carbon': 0.12,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 1.21,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 123,
#   'BioCap': 0.98,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Burundi',
#   'HDI': 0.39,
#   'Footprint_Crop': 0.21,
#   'Footprint_Graze': 0.07,
#   'Footprint_Forest': 0.45,
#   'Footprint_Carbon': 0.04,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 0.8,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 56,
#   'BioCap': 0.32,
#   'BioCap_RD': 0,
#   'Data_Quality': 4},
#  {'Country': 'Cameroon',
#   'HDI': 0.5,
#   'Footprint_Crop': 0.54,
#   'Footprint_Graze': 0.1,
#   'Footprint_Forest': 0.21,
#   'Footprint_Carbon': 0.19,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 1.17,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 408,
#   'BioCap': 1.69,
#   'BioCap_RD': 1,
#   'Data_Quality': 6},
#  {'Country': 'Canada',
#   'HDI': 0.91,
#   'Footprint_Crop': 1.46,
#   'Footprint_Graze': 0.33,
#   'Footprint_Forest': 1.2,
#   'Footprint_Carbon': 5.0,
#   'Footprint_Fish': 0.12,
#   'Footprint_Total': 8.17,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 19276,
#   'BioCap': 16.01,
#   'BioCap_RD': 8,
#   'Data_Quality': 5},
#  {'Country': 'Central African Republic',
#   'HDI': 0.37,
#   'Footprint_Crop': 0.3,
#   'Footprint_Graze': 0.55,
#   'Footprint_Forest': 0.26,
#   'Footprint_Carbon': 0.08,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 1.24,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 19,
#   'BioCap': 7.87,
#   'BioCap_RD': 7,
#   'Data_Quality': 6},
#  {'Country': 'Chad',
#   'HDI': 0.39,
#   'Footprint_Crop': 0.36,
#   'Footprint_Graze': 0.75,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 0.01,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.46,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 288,
#   'BioCap': 2.03,
#   'BioCap_RD': 1,
#   'Data_Quality': 6},
#  {'Country': 'Chile',
#   'HDI': 0.83,
#   'Footprint_Crop': 0.61,
#   'Footprint_Graze': 0.33,
#   'Footprint_Forest': 0.99,
#   'Footprint_Carbon': 2.04,
#   'Footprint_Fish': 0.25,
#   'Footprint_Total': 4.36,
#   'Land_Urban': 0.15,
#   'Emission_CO2': 540,
#   'BioCap': 3.63,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'China',
#   'HDI': 0.72,
#   'Footprint_Crop': 0.55,
#   'Footprint_Graze': 0.13,
#   'Footprint_Forest': 0.19,
#   'Footprint_Carbon': 2.32,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 3.38,
#   'Land_Urban': 0.12,
#   'Emission_CO2': 101394,
#   'BioCap': 0.94,
#   'BioCap_RD': -2,
#   'Data_Quality': 6},
#  {'Country': 'Colombia',
#   'HDI': 0.72,
#   'Footprint_Crop': 0.35,
#   'Footprint_Graze': 0.58,
#   'Footprint_Forest': 0.16,
#   'Footprint_Carbon': 0.67,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 1.87,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 5380,
#   'BioCap': 3.6,
#   'BioCap_RD': 2,
#   'Data_Quality': 6},
#  {'Country': 'Comoros',
#   'HDI': 0.5,
#   'Footprint_Crop': 0.33,
#   'Footprint_Graze': 0.03,
#   'Footprint_Forest': 0.18,
#   'Footprint_Carbon': 0.25,
#   'Footprint_Fish': 0.25,
#   'Footprint_Total': 1.03,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 3,
#   'BioCap': 0.32,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Congo',
#   'HDI': 0.57,
#   'Footprint_Crop': 0.22,
#   'Footprint_Graze': 0.09,
#   'Footprint_Forest': 0.38,
#   'Footprint_Carbon': 0.47,
#   'Footprint_Fish': 0.1,
#   'Footprint_Total': 1.29,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 648,
#   'BioCap': 10.91,
#   'BioCap_RD': 10,
#   'Data_Quality': 5},
#  {'Country': 'Costa Rica',
#   'HDI': 0.76,
#   'Footprint_Crop': 0.4,
#   'Footprint_Graze': 0.21,
#   'Footprint_Forest': 0.68,
#   'Footprint_Carbon': 1.37,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 2.84,
#   'Land_Urban': 0.1,
#   'Emission_CO2': 110,
#   'BioCap': 1.53,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Croatia',
#   'HDI': 0.82,
#   'Footprint_Crop': 0.74,
#   'Footprint_Graze': 0.13,
#   'Footprint_Forest': 0.72,
#   'Footprint_Carbon': 2.21,
#   'Footprint_Fish': 0.06,
#   'Footprint_Total': 3.92,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 182,
#   'BioCap': 2.8,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Cuba',
#   'HDI': 0.77,
#   'Footprint_Crop': 0.48,
#   'Footprint_Graze': 0.11,
#   'Footprint_Forest': 0.09,
#   'Footprint_Carbon': 1.23,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 1.95,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 212,
#   'BioCap': 0.76,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Cyprus',
#   'HDI': 0.85,
#   'Footprint_Crop': 0.77,
#   'Footprint_Graze': 0.08,
#   'Footprint_Forest': 0.23,
#   'Footprint_Carbon': 2.94,
#   'Footprint_Fish': 0.14,
#   'Footprint_Total': 4.21,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 5,
#   'BioCap': 0.34,
#   'BioCap_RD': -4,
#   'Data_Quality': 5},
#  {'Country': 'Denmark',
#   'HDI': 0.92,
#   'Footprint_Crop': 1.18,
#   'Footprint_Graze': 0.47,
#   'Footprint_Forest': 0.77,
#   'Footprint_Carbon': 2.6,
#   'Footprint_Fish': 0.24,
#   'Footprint_Total': 5.51,
#   'Land_Urban': 0.25,
#   'Emission_CO2': 666,
#   'BioCap': 4.78,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Dominica',
#   'HDI': 0.72,
#   'Footprint_Crop': 0.64,
#   'Footprint_Graze': 0.15,
#   'Footprint_Forest': 0.14,
#   'Footprint_Carbon': 1.47,
#   'Footprint_Fish': 0.17,
#   'Footprint_Total': 2.57,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 0,
#   'BioCap': 1.03,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Dominican Republic',
#   'HDI': 0.71,
#   'Footprint_Crop': 0.35,
#   'Footprint_Graze': 0.12,
#   'Footprint_Forest': 0.12,
#   'Footprint_Carbon': 0.86,
#   'Footprint_Fish': 0.04,
#   'Footprint_Total': 1.53,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 28,
#   'BioCap': 0.56,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Ecuador',
#   'HDI': 0.73,
#   'Footprint_Crop': 0.3,
#   'Footprint_Graze': 0.3,
#   'Footprint_Forest': 0.24,
#   'Footprint_Carbon': 1.08,
#   'Footprint_Fish': 0.18,
#   'Footprint_Total': 2.17,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 1247,
#   'BioCap': 2.2,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Egypt',
#   'HDI': 0.69,
#   'Footprint_Crop': 0.68,
#   'Footprint_Graze': 0.08,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 1.02,
#   'Footprint_Fish': 0.04,
#   'Footprint_Total': 2.15,
#   'Land_Urban': 0.15,
#   'Emission_CO2': 3509,
#   'BioCap': 0.56,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'El Salvador',
#   'HDI': 0.66,
#   'Footprint_Crop': 0.44,
#   'Footprint_Graze': 0.21,
#   'Footprint_Forest': 0.4,
#   'Footprint_Carbon': 0.84,
#   'Footprint_Fish': 0.14,
#   'Footprint_Total': 2.07,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 86,
#   'BioCap': 0.61,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Equatorial Guinea',
#   'HDI': 0.58,
#   'Footprint_Crop': 0.27,
#   'Footprint_Graze': 0.02,
#   'Footprint_Forest': 0.26,
#   'Footprint_Carbon': 3.17,
#   'Footprint_Fish': 0.22,
#   'Footprint_Total': 3.97,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 841,
#   'BioCap': 4.4,
#   'BioCap_RD': 0,
#   'Data_Quality': 3},
#  {'Country': 'Eritrea',
#   'HDI': 0.39,
#   'Footprint_Crop': 0.1,
#   'Footprint_Graze': 0.18,
#   'Footprint_Forest': 0.06,
#   'Footprint_Carbon': 0.03,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 0.42,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 27,
#   'BioCap': 1.3,
#   'BioCap_RD': 1,
#   'Data_Quality': 5},
#  {'Country': 'Ethiopia',
#   'HDI': 0.43,
#   'Footprint_Crop': 0.31,
#   'Footprint_Graze': 0.12,
#   'Footprint_Forest': 0.46,
#   'Footprint_Carbon': 0.07,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 1.02,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 1308,
#   'BioCap': 0.58,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Fiji',
#   'HDI': 0.72,
#   'Footprint_Crop': 0.55,
#   'Footprint_Graze': 0.2,
#   'Footprint_Forest': 0.42,
#   'Footprint_Carbon': 1.06,
#   'Footprint_Fish': 0.62,
#   'Footprint_Total': 2.9,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 8,
#   'BioCap': 2.37,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'France',
#   'HDI': 0.89,
#   'Footprint_Crop': 1.23,
#   'Footprint_Graze': 0.27,
#   'Footprint_Forest': 0.53,
#   'Footprint_Carbon': 2.71,
#   'Footprint_Fish': 0.19,
#   'Footprint_Total': 5.14,
#   'Land_Urban': 0.21,
#   'Emission_CO2': 5694,
#   'BioCap': 3.11,
#   'BioCap_RD': -2,
#   'Data_Quality': 6},
#  {'Country': 'Gabon',
#   'HDI': 0.67,
#   'Footprint_Crop': 0.53,
#   'Footprint_Graze': 0.13,
#   'Footprint_Forest': 0.79,
#   'Footprint_Carbon': 0.43,
#   'Footprint_Fish': 0.11,
#   'Footprint_Total': 2.02,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 559,
#   'BioCap': 26.31,
#   'BioCap_RD': 24,
#   'Data_Quality': 3},
#  {'Country': 'Gambia',
#   'HDI': 0.44,
#   'Footprint_Crop': 0.46,
#   'Footprint_Graze': 0.05,
#   'Footprint_Forest': 0.2,
#   'Footprint_Carbon': 0.21,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 1.03,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 7,
#   'BioCap': 0.82,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Georgia',
#   'HDI': 0.75,
#   'Footprint_Crop': 0.39,
#   'Footprint_Graze': 0.2,
#   'Footprint_Forest': 0.1,
#   'Footprint_Carbon': 0.83,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 1.58,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 61,
#   'BioCap': 1.17,
#   'BioCap_RD': 0,
#   'Data_Quality': 3},
#  {'Country': 'Germany',
#   'HDI': 0.91,
#   'Footprint_Crop': 1.1,
#   'Footprint_Graze': 0.14,
#   'Footprint_Forest': 0.48,
#   'Footprint_Carbon': 3.28,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 5.3,
#   'Land_Urban': 0.24,
#   'Emission_CO2': 5004,
#   'BioCap': 2.27,
#   'BioCap_RD': -3,
#   'Data_Quality': 5},
#  {'Country': 'Ghana',
#   'HDI': 0.57,
#   'Footprint_Crop': 0.56,
#   'Footprint_Graze': 0.07,
#   'Footprint_Forest': 0.65,
#   'Footprint_Carbon': 0.43,
#   'Footprint_Fish': 0.19,
#   'Footprint_Total': 1.97,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 410,
#   'BioCap': 1.35,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Greece',
#   'HDI': 0.86,
#   'Footprint_Crop': 1.07,
#   'Footprint_Graze': 0.35,
#   'Footprint_Forest': 0.24,
#   'Footprint_Carbon': 2.58,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 4.38,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 368,
#   'BioCap': 1.61,
#   'BioCap_RD': -3,
#   'Data_Quality': 5},
#  {'Country': 'Guatemala',
#   'HDI': 0.62,
#   'Footprint_Crop': 0.37,
#   'Footprint_Graze': 0.16,
#   'Footprint_Forest': 0.58,
#   'Footprint_Carbon': 0.7,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.89,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 327,
#   'BioCap': 0.99,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Guinea',
#   'HDI': 0.41,
#   'Footprint_Crop': 0.39,
#   'Footprint_Graze': 0.32,
#   'Footprint_Forest': 0.45,
#   'Footprint_Carbon': 0.16,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 1.41,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 113,
#   'BioCap': 2.09,
#   'BioCap_RD': 1,
#   'Data_Quality': 5},
#  {'Country': 'Guinea-Bissau',
#   'HDI': 0.42,
#   'Footprint_Crop': 0.35,
#   'Footprint_Graze': 0.36,
#   'Footprint_Forest': 0.67,
#   'Footprint_Carbon': 0.09,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.53,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 25,
#   'BioCap': 3.03,
#   'BioCap_RD': 1,
#   'Data_Quality': 6},
#  {'Country': 'Guyana',
#   'HDI': 0.63,
#   'Footprint_Crop': 0.7,
#   'Footprint_Graze': 0.22,
#   'Footprint_Forest': 0.77,
#   'Footprint_Carbon': 1.25,
#   'Footprint_Fish': 0.06,
#   'Footprint_Total': 3.07,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 7,
#   'BioCap': 66.58,
#   'BioCap_RD': 64,
#   'Data_Quality': 5},
#  {'Country': 'Haiti',
#   'HDI': 0.48,
#   'Footprint_Crop': 0.27,
#   'Footprint_Graze': 0.04,
#   'Footprint_Forest': 0.1,
#   'Footprint_Carbon': 0.15,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 0.61,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 136,
#   'BioCap': 0.27,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Honduras',
#   'HDI': 0.61,
#   'Footprint_Crop': 0.28,
#   'Footprint_Graze': 0.25,
#   'Footprint_Forest': 0.5,
#   'Footprint_Carbon': 0.6,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 1.68,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 105,
#   'BioCap': 1.77,
#   'BioCap_RD': 0,
#   'Data_Quality': 3},
#  {'Country': 'Hungary',
#   'HDI': 0.82,
#   'Footprint_Crop': 0.42,
#   'Footprint_Graze': 0.08,
#   'Footprint_Forest': 0.36,
#   'Footprint_Carbon': 1.9,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 2.92,
#   'Land_Urban': 0.13,
#   'Emission_CO2': 423,
#   'BioCap': 2.17,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'India',
#   'HDI': 0.6,
#   'Footprint_Crop': 0.34,
#   'Footprint_Graze': 0.01,
#   'Footprint_Forest': 0.14,
#   'Footprint_Carbon': 0.61,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 1.16,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 23103,
#   'BioCap': 0.45,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Indonesia',
#   'HDI': 0.68,
#   'Footprint_Crop': 0.44,
#   'Footprint_Graze': 0.03,
#   'Footprint_Forest': 0.2,
#   'Footprint_Carbon': 0.64,
#   'Footprint_Fish': 0.21,
#   'Footprint_Total': 1.58,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 19481,
#   'BioCap': 1.26,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Iraq',
#   'HDI': 0.65,
#   'Footprint_Crop': 0.43,
#   'Footprint_Graze': 0.03,
#   'Footprint_Forest': 0.01,
#   'Footprint_Carbon': 1.36,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.88,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 6744,
#   'BioCap': 0.29,
#   'BioCap_RD': -2,
#   'Data_Quality': 3},
#  {'Country': 'Ireland',
#   'HDI': 0.91,
#   'Footprint_Crop': 1.08,
#   'Footprint_Graze': 0.49,
#   'Footprint_Forest': 0.46,
#   'Footprint_Carbon': 3.22,
#   'Footprint_Fish': 0.18,
#   'Footprint_Total': 5.57,
#   'Land_Urban': 0.13,
#   'Emission_CO2': 84,
#   'BioCap': 3.73,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Israel',
#   'HDI': 0.89,
#   'Footprint_Crop': 0.89,
#   'Footprint_Graze': 0.22,
#   'Footprint_Forest': 0.36,
#   'Footprint_Carbon': 4.59,
#   'Footprint_Fish': 0.07,
#   'Footprint_Total': 6.22,
#   'Land_Urban': 0.08,
#   'Emission_CO2': 313,
#   'BioCap': 0.35,
#   'BioCap_RD': -6,
#   'Data_Quality': 6},
#  {'Country': 'Italy',
#   'HDI': 0.87,
#   'Footprint_Crop': 0.91,
#   'Footprint_Graze': 0.32,
#   'Footprint_Forest': 0.42,
#   'Footprint_Carbon': 2.77,
#   'Footprint_Fish': 0.12,
#   'Footprint_Total': 4.61,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 1539,
#   'BioCap': 1.08,
#   'BioCap_RD': -4,
#   'Data_Quality': 6},
#  {'Country': 'Jamaica',
#   'HDI': 0.72,
#   'Footprint_Crop': 0.41,
#   'Footprint_Graze': 0.09,
#   'Footprint_Forest': 0.18,
#   'Footprint_Carbon': 1.09,
#   'Footprint_Fish': 0.07,
#   'Footprint_Total': 1.89,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 8,
#   'BioCap': 0.43,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Japan',
#   'HDI': 0.89,
#   'Footprint_Crop': 0.53,
#   'Footprint_Graze': 0.1,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 3.69,
#   'Footprint_Fish': 0.33,
#   'Footprint_Total': 5.02,
#   'Land_Urban': 0.1,
#   'Emission_CO2': 1114,
#   'BioCap': 0.72,
#   'BioCap_RD': -4,
#   'Data_Quality': 6},
#  {'Country': 'Jordan',
#   'HDI': 0.75,
#   'Footprint_Crop': 0.54,
#   'Footprint_Graze': 0.18,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 1.09,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 2.1,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 7,
#   'BioCap': 0.21,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Kazakhstan',
#   'HDI': 0.78,
#   'Footprint_Crop': 0.58,
#   'Footprint_Graze': 0.19,
#   'Footprint_Forest': 0.12,
#   'Footprint_Carbon': 4.59,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 5.55,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 7091,
#   'BioCap': 3.41,
#   'BioCap_RD': -2,
#   'Data_Quality': 3},
#  {'Country': 'Kenya',
#   'HDI': 0.54,
#   'Footprint_Crop': 0.25,
#   'Footprint_Graze': 0.23,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 0.2,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 1.03,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 750,
#   'BioCap': 0.51,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Kuwait',
#   'HDI': 0.82,
#   'Footprint_Crop': 0.55,
#   'Footprint_Graze': 0.24,
#   'Footprint_Forest': 0.21,
#   'Footprint_Carbon': 6.89,
#   'Footprint_Fish': 0.09,
#   'Footprint_Total': 8.13,
#   'Land_Urban': 0.15,
#   'Emission_CO2': 6941,
#   'BioCap': 0.55,
#   'BioCap_RD': -8,
#   'Data_Quality': 3},
#  {'Country': 'Kyrgyzstan',
#   'HDI': 0.65,
#   'Footprint_Crop': 0.59,
#   'Footprint_Graze': 0.18,
#   'Footprint_Forest': 0.09,
#   'Footprint_Carbon': 0.95,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.91,
#   'Land_Urban': 0.08,
#   'Emission_CO2': 80,
#   'BioCap': 1.3,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': "Lao People's Democratic Republic",
#   'HDI': 0.56,
#   'Footprint_Crop': 0.57,
#   'Footprint_Graze': 0.08,
#   'Footprint_Forest': 0.36,
#   'Footprint_Carbon': 0.09,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.22,
#   'Land_Urban': 0.11,
#   'Emission_CO2': 72,
#   'BioCap': 1.62,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Latvia',
#   'HDI': 0.81,
#   'Footprint_Crop': 2.28,
#   'Footprint_Graze': 0.09,
#   'Footprint_Forest': 2.02,
#   'Footprint_Carbon': 1.66,
#   'Footprint_Fish': 0.11,
#   'Footprint_Total': 6.29,
#   'Land_Urban': 0.13,
#   'Emission_CO2': 108,
#   'BioCap': 9.55,
#   'BioCap_RD': 3,
#   'Data_Quality': 5},
#  {'Country': 'Lebanon',
#   'HDI': 0.76,
#   'Footprint_Crop': 0.67,
#   'Footprint_Graze': 0.3,
#   'Footprint_Forest': 0.25,
#   'Footprint_Carbon': 2.52,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 3.84,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 7,
#   'BioCap': 0.33,
#   'BioCap_RD': -4,
#   'Data_Quality': 6},
#  {'Country': 'Lesotho',
#   'HDI': 0.48,
#   'Footprint_Crop': 0.22,
#   'Footprint_Graze': 0.49,
#   'Footprint_Forest': 0.42,
#   'Footprint_Carbon': 0.51,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 1.66,
#   'Land_Urban': 0.01,
#   'Emission_CO2': 31,
#   'BioCap': 0.78,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Liberia',
#   'HDI': 0.42,
#   'Footprint_Crop': 0.23,
#   'Footprint_Graze': 0.03,
#   'Footprint_Forest': 0.75,
#   'Footprint_Carbon': 0.14,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 1.21,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 73,
#   'BioCap': 2.57,
#   'BioCap_RD': 1,
#   'Data_Quality': 3},
#  {'Country': 'Lithuania',
#   'HDI': 0.83,
#   'Footprint_Crop': 1.89,
#   'Footprint_Graze': 0.21,
#   'Footprint_Forest': 1.28,
#   'Footprint_Carbon': 2.15,
#   'Footprint_Fish': 0.16,
#   'Footprint_Total': 5.83,
#   'Land_Urban': 0.15,
#   'Emission_CO2': 74,
#   'BioCap': 5.67,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Luxembourg',
#   'HDI': 0.89,
#   'Footprint_Crop': 1.1,
#   'Footprint_Graze': 0.76,
#   'Footprint_Forest': 1.03,
#   'Footprint_Carbon': 12.65,
#   'Footprint_Fish': 0.13,
#   'Footprint_Total': 15.82,
#   'Land_Urban': 0.14,
#   'Emission_CO2': 6,
#   'BioCap': 1.68,
#   'BioCap_RD': -14,
#   'Data_Quality': 5},
#  {'Country': 'Madagascar',
#   'HDI': 0.51,
#   'Footprint_Crop': 0.27,
#   'Footprint_Graze': 0.34,
#   'Footprint_Forest': 0.24,
#   'Footprint_Carbon': 0.07,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 0.99,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 129,
#   'BioCap': 2.63,
#   'BioCap_RD': 2,
#   'Data_Quality': 6},
#  {'Country': 'Malawi',
#   'HDI': 0.43,
#   'Footprint_Crop': 0.43,
#   'Footprint_Graze': 0.05,
#   'Footprint_Forest': 0.2,
#   'Footprint_Carbon': 0.07,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 0.81,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 89,
#   'BioCap': 0.66,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Malaysia',
#   'HDI': 0.77,
#   'Footprint_Crop': 0.67,
#   'Footprint_Graze': 0.12,
#   'Footprint_Forest': 0.38,
#   'Footprint_Carbon': 2.1,
#   'Footprint_Fish': 0.36,
#   'Footprint_Total': 3.71,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 3738,
#   'BioCap': 2.41,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Mali',
#   'HDI': 0.41,
#   'Footprint_Crop': 0.52,
#   'Footprint_Graze': 0.66,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 0.1,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 1.53,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 55,
#   'BioCap': 1.58,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Mauritania',
#   'HDI': 0.5,
#   'Footprint_Crop': 0.39,
#   'Footprint_Graze': 1.2,
#   'Footprint_Forest': 0.21,
#   'Footprint_Carbon': 0.55,
#   'Footprint_Fish': 0.15,
#   'Footprint_Total': 2.54,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 31,
#   'BioCap': 4.48,
#   'BioCap_RD': 2,
#   'Data_Quality': 3},
#  {'Country': 'Mauritius',
#   'HDI': 0.77,
#   'Footprint_Crop': 0.52,
#   'Footprint_Graze': 0.22,
#   'Footprint_Forest': 0.18,
#   'Footprint_Carbon': 1.99,
#   'Footprint_Fish': 0.55,
#   'Footprint_Total': 3.46,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 10,
#   'BioCap': 0.71,
#   'BioCap_RD': -3,
#   'Data_Quality': 5},
#  {'Country': 'Mexico',
#   'HDI': 0.75,
#   'Footprint_Crop': 0.55,
#   'Footprint_Graze': 0.24,
#   'Footprint_Forest': 0.25,
#   'Footprint_Carbon': 1.74,
#   'Footprint_Fish': 0.06,
#   'Footprint_Total': 2.89,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 8514,
#   'BioCap': 1.27,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Mongolia',
#   'HDI': 0.71,
#   'Footprint_Crop': 0.29,
#   'Footprint_Graze': 3.47,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 2.09,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 6.08,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 677,
#   'BioCap': 15.66,
#   'BioCap_RD': 10,
#   'Data_Quality': 3},
#  {'Country': 'Montenegro',
#   'HDI': 0.8,
#   'Footprint_Crop': 0.64,
#   'Footprint_Graze': 0.33,
#   'Footprint_Forest': 0.62,
#   'Footprint_Carbon': 2.13,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 3.78,
#   'Land_Urban': 0.01,
#   'Emission_CO2': 29,
#   'BioCap': 3.24,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Morocco',
#   'HDI': 0.62,
#   'Footprint_Crop': 0.6,
#   'Footprint_Graze': 0.17,
#   'Footprint_Forest': 0.14,
#   'Footprint_Carbon': 0.67,
#   'Footprint_Fish': 0.06,
#   'Footprint_Total': 1.68,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 78,
#   'BioCap': 0.71,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Mozambique',
#   'HDI': 0.41,
#   'Footprint_Crop': 0.31,
#   'Footprint_Graze': 0.03,
#   'Footprint_Forest': 0.29,
#   'Footprint_Carbon': 0.17,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 0.87,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 779,
#   'BioCap': 2.06,
#   'BioCap_RD': 1,
#   'Data_Quality': 5},
#  {'Country': 'Myanmar',
#   'HDI': 0.53,
#   'Footprint_Crop': 0.8,
#   'Footprint_Graze': 0.01,
#   'Footprint_Forest': 0.32,
#   'Footprint_Carbon': 0.09,
#   'Footprint_Fish': 0.1,
#   'Footprint_Total': 1.43,
#   'Land_Urban': 0.11,
#   'Emission_CO2': 1078,
#   'BioCap': 1.84,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Namibia',
#   'HDI': 0.62,
#   'Footprint_Crop': 0.33,
#   'Footprint_Graze': 0.23,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 1.02,
#   'Footprint_Fish': 0.72,
#   'Footprint_Total': 2.48,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 19,
#   'BioCap': 6.88,
#   'BioCap_RD': 4,
#   'Data_Quality': 3},
#  {'Country': 'Nepal',
#   'HDI': 0.54,
#   'Footprint_Crop': 0.43,
#   'Footprint_Graze': 0.07,
#   'Footprint_Forest': 0.21,
#   'Footprint_Carbon': 0.16,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 0.98,
#   'Land_Urban': 0.11,
#   'Emission_CO2': 451,
#   'BioCap': 0.59,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Netherlands',
#   'HDI': 0.92,
#   'Footprint_Crop': 0.76,
#   'Footprint_Graze': 0.58,
#   'Footprint_Forest': 0.38,
#   'Footprint_Carbon': 3.23,
#   'Footprint_Fish': 0.16,
#   'Footprint_Total': 5.28,
#   'Land_Urban': 0.17,
#   'Emission_CO2': 2447,
#   'BioCap': 1.17,
#   'BioCap_RD': -4,
#   'Data_Quality': 6},
#  {'Country': 'New Zealand',
#   'HDI': 0.91,
#   'Footprint_Crop': 0.63,
#   'Footprint_Graze': 0.23,
#   'Footprint_Forest': 1.08,
#   'Footprint_Carbon': 2.84,
#   'Footprint_Fish': 0.7,
#   'Footprint_Total': 5.6,
#   'Land_Urban': 0.13,
#   'Emission_CO2': 783,
#   'BioCap': 10.14,
#   'BioCap_RD': 5,
#   'Data_Quality': 3},
#  {'Country': 'Nicaragua',
#   'HDI': 0.63,
#   'Footprint_Crop': 0.34,
#   'Footprint_Graze': 0.12,
#   'Footprint_Forest': 0.42,
#   'Footprint_Carbon': 0.45,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 1.39,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 91,
#   'BioCap': 2.25,
#   'BioCap_RD': 1,
#   'Data_Quality': 5},
#  {'Country': 'Niger',
#   'HDI': 0.34,
#   'Footprint_Crop': 0.67,
#   'Footprint_Graze': 0.48,
#   'Footprint_Forest': 0.26,
#   'Footprint_Carbon': 0.1,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 1.56,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 101,
#   'BioCap': 1.24,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Nigeria',
#   'HDI': 0.5,
#   'Footprint_Crop': 0.53,
#   'Footprint_Graze': 0.1,
#   'Footprint_Forest': 0.19,
#   'Footprint_Carbon': 0.21,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 1.16,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 10851,
#   'BioCap': 0.7,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Oman',
#   'HDI': 0.79,
#   'Footprint_Crop': 0.57,
#   'Footprint_Graze': 0.4,
#   'Footprint_Forest': 0.15,
#   'Footprint_Carbon': 5.8,
#   'Footprint_Fish': 0.4,
#   'Footprint_Total': 7.52,
#   'Land_Urban': 0.19,
#   'Emission_CO2': 3101,
#   'BioCap': 1.92,
#   'BioCap_RD': -6,
#   'Data_Quality': 3},
#  {'Country': 'Pakistan',
#   'HDI': 0.53,
#   'Footprint_Crop': 0.27,
#   'Footprint_Graze': 0.01,
#   'Footprint_Forest': 0.08,
#   'Footprint_Carbon': 0.38,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 0.79,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 2202,
#   'BioCap': 0.35,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Panama',
#   'HDI': 0.77,
#   'Footprint_Crop': 0.36,
#   'Footprint_Graze': 0.4,
#   'Footprint_Forest': 0.19,
#   'Footprint_Carbon': 1.44,
#   'Footprint_Fish': 0.37,
#   'Footprint_Total': 2.79,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 31,
#   'BioCap': 2.94,
#   'BioCap_RD': 0,
#   'Data_Quality': 3},
#  {'Country': 'Papua New Guinea',
#   'HDI': 0.5,
#   'Footprint_Crop': 0.3,
#   'Footprint_Graze': 0.05,
#   'Footprint_Forest': 0.36,
#   'Footprint_Carbon': 0.35,
#   'Footprint_Fish': 0.73,
#   'Footprint_Total': 1.91,
#   'Land_Urban': 0.13,
#   'Emission_CO2': 114,
#   'BioCap': 3.92,
#   'BioCap_RD': 2,
#   'Data_Quality': 3},
#  {'Country': 'Paraguay',
#   'HDI': 0.67,
#   'Footprint_Crop': 1.11,
#   'Footprint_Graze': 1.1,
#   'Footprint_Forest': 0.83,
#   'Footprint_Carbon': 0.97,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 4.16,
#   'Land_Urban': 0.14,
#   'Emission_CO2': 325,
#   'BioCap': 10.52,
#   'BioCap_RD': 6,
#   'Data_Quality': 3},
#  {'Country': 'Peru',
#   'HDI': 0.73,
#   'Footprint_Crop': 0.5,
#   'Footprint_Graze': 0.51,
#   'Footprint_Forest': 0.19,
#   'Footprint_Carbon': 0.67,
#   'Footprint_Fish': 0.33,
#   'Footprint_Total': 2.28,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 1020,
#   'BioCap': 3.97,
#   'BioCap_RD': 2,
#   'Data_Quality': 6},
#  {'Country': 'Philippines',
#   'HDI': 0.66,
#   'Footprint_Crop': 0.36,
#   'Footprint_Graze': 0.03,
#   'Footprint_Forest': 0.09,
#   'Footprint_Carbon': 0.34,
#   'Footprint_Fish': 0.23,
#   'Footprint_Total': 1.1,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 991,
#   'BioCap': 0.54,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Poland',
#   'HDI': 0.84,
#   'Footprint_Crop': 0.84,
#   'Footprint_Graze': 0.04,
#   'Footprint_Forest': 0.78,
#   'Footprint_Carbon': 2.64,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 4.44,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 2819,
#   'BioCap': 2.08,
#   'BioCap_RD': -2,
#   'Data_Quality': 6},
#  {'Country': 'Portugal',
#   'HDI': 0.83,
#   'Footprint_Crop': 1.03,
#   'Footprint_Graze': 0.25,
#   'Footprint_Forest': 0.09,
#   'Footprint_Carbon': 2.15,
#   'Footprint_Fish': 0.31,
#   'Footprint_Total': 3.88,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 250,
#   'BioCap': 1.51,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Qatar',
#   'HDI': 0.85,
#   'Footprint_Crop': 0.57,
#   'Footprint_Graze': 0.27,
#   'Footprint_Forest': 0.15,
#   'Footprint_Carbon': 9.57,
#   'Footprint_Fish': 0.19,
#   'Footprint_Total': 10.8,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 9166,
#   'BioCap': 1.24,
#   'BioCap_RD': -10,
#   'Data_Quality': 3},
#  {'Country': 'Romania',
#   'HDI': 0.79,
#   'Footprint_Crop': 0.72,
#   'Footprint_Graze': 0.05,
#   'Footprint_Forest': 0.33,
#   'Footprint_Carbon': 1.46,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 2.71,
#   'Land_Urban': 0.12,
#   'Emission_CO2': 1109,
#   'BioCap': 2.32,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Russian Federation',
#   'HDI': 0.79,
#   'Footprint_Crop': 0.77,
#   'Footprint_Graze': 0.15,
#   'Footprint_Forest': 0.67,
#   'Footprint_Carbon': 3.87,
#   'Footprint_Fish': 0.19,
#   'Footprint_Total': 5.69,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 54829,
#   'BioCap': 6.79,
#   'BioCap_RD': 1,
#   'Data_Quality': 6},
#  {'Country': 'Rwanda',
#   'HDI': 0.48,
#   'Footprint_Crop': 0.43,
#   'Footprint_Graze': 0.05,
#   'Footprint_Forest': 0.25,
#   'Footprint_Carbon': 0.07,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 0.87,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 84,
#   'BioCap': 0.54,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Saint Kitts and Nevis',
#   'HDI': 0.74,
#   'Footprint_Crop': 0.51,
#   'Footprint_Graze': 0.18,
#   'Footprint_Forest': 0.09,
#   'Footprint_Carbon': 3.34,
#   'Footprint_Fish': 0.81,
#   'Footprint_Total': 4.94,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 0,
#   'BioCap': 0.62,
#   'BioCap_RD': -4,
#   'Data_Quality': 3},
#  {'Country': 'Saint Lucia',
#   'HDI': 0.73,
#   'Footprint_Crop': 0.38,
#   'Footprint_Graze': 0.1,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 1.56,
#   'Footprint_Fish': 0.23,
#   'Footprint_Total': 2.45,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 0,
#   'BioCap': 0.34,
#   'BioCap_RD': -2,
#   'Data_Quality': 3},
#  {'Country': 'Samoa',
#   'HDI': 0.7,
#   'Footprint_Crop': 0.97,
#   'Footprint_Graze': 0.16,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 0.96,
#   'Footprint_Fish': 0.42,
#   'Footprint_Total': 2.77,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 2,
#   'BioCap': 1.93,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Sao Tome and Principe',
#   'HDI': 0.55,
#   'Footprint_Crop': 0.36,
#   'Footprint_Graze': 0.02,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 0.37,
#   'Footprint_Fish': 0.47,
#   'Footprint_Total': 1.49,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 1,
#   'BioCap': 0.87,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Saudi Arabia',
#   'HDI': 0.83,
#   'Footprint_Crop': 0.74,
#   'Footprint_Graze': 0.27,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 4.21,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 5.61,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 25904,
#   'BioCap': 0.5,
#   'BioCap_RD': -5,
#   'Data_Quality': 3},
#  {'Country': 'Senegal',
#   'HDI': 0.46,
#   'Footprint_Crop': 0.34,
#   'Footprint_Graze': 0.21,
#   'Footprint_Forest': 0.21,
#   'Footprint_Carbon': 0.3,
#   'Footprint_Fish': 0.12,
#   'Footprint_Total': 1.21,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 77,
#   'BioCap': 1.05,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Serbia',
#   'HDI': 0.76,
#   'Footprint_Crop': 0.49,
#   'Footprint_Graze': 0.02,
#   'Footprint_Forest': 0.46,
#   'Footprint_Carbon': 1.66,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 2.7,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 393,
#   'BioCap': 1.25,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Sierra Leone',
#   'HDI': 0.4,
#   'Footprint_Crop': 0.47,
#   'Footprint_Graze': 0.11,
#   'Footprint_Forest': 0.38,
#   'Footprint_Carbon': 0.07,
#   'Footprint_Fish': 0.15,
#   'Footprint_Total': 1.24,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 53,
#   'BioCap': 1.24,
#   'BioCap_RD': 0,
#   'Data_Quality': 6},
#  {'Country': 'Singapore',
#   'HDI': 0.91,
#   'Footprint_Crop': 0.67,
#   'Footprint_Graze': 0.24,
#   'Footprint_Forest': 0.91,
#   'Footprint_Carbon': 5.91,
#   'Footprint_Fish': 0.22,
#   'Footprint_Total': 7.97,
#   'Land_Urban': 0.03,
#   'Emission_CO2': 27,
#   'BioCap': 0.05,
#   'BioCap_RD': -8,
#   'Data_Quality': 5},
#  {'Country': 'Slovakia',
#   'HDI': 0.84,
#   'Footprint_Crop': 0.31,
#   'Footprint_Graze': 0.08,
#   'Footprint_Forest': 0.72,
#   'Footprint_Carbon': 2.82,
#   'Footprint_Fish': 0.03,
#   'Footprint_Total': 4.06,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 264,
#   'BioCap': 2.71,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Slovenia',
#   'HDI': 0.88,
#   'Footprint_Crop': 0.64,
#   'Footprint_Graze': 0.17,
#   'Footprint_Forest': 0.65,
#   'Footprint_Carbon': 4.27,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 5.81,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 154,
#   'BioCap': 2.35,
#   'BioCap_RD': -3,
#   'Data_Quality': 6},
#  {'Country': 'Solomon Islands',
#   'HDI': 0.5,
#   'Footprint_Crop': 0.47,
#   'Footprint_Graze': 0.03,
#   'Footprint_Forest': 0.09,
#   'Footprint_Carbon': 0.0,
#   'Footprint_Fish': 0.46,
#   'Footprint_Total': 1.29,
#   'Land_Urban': 0.23,
#   'Emission_CO2': 3,
#   'BioCap': 4.36,
#   'BioCap_RD': 3,
#   'Data_Quality': 3},
#  {'Country': 'South Africa',
#   'HDI': 0.66,
#   'Footprint_Crop': 0.44,
#   'Footprint_Graze': 0.11,
#   'Footprint_Forest': 0.29,
#   'Footprint_Carbon': 2.34,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 3.31,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 7102,
#   'BioCap': 1.15,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Spain',
#   'HDI': 0.87,
#   'Footprint_Crop': 0.78,
#   'Footprint_Graze': 0.15,
#   'Footprint_Forest': 0.17,
#   'Footprint_Carbon': 2.22,
#   'Footprint_Fish': 0.32,
#   'Footprint_Total': 3.67,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 1432,
#   'BioCap': 1.25,
#   'BioCap_RD': -2,
#   'Data_Quality': 6},
#  {'Country': 'Sri Lanka',
#   'HDI': 0.75,
#   'Footprint_Crop': 0.31,
#   'Footprint_Graze': 0.01,
#   'Footprint_Forest': 0.16,
#   'Footprint_Carbon': 0.52,
#   'Footprint_Fish': 0.27,
#   'Footprint_Total': 1.32,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 179,
#   'BioCap': 0.44,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Suriname',
#   'HDI': 0.71,
#   'Footprint_Crop': 0.43,
#   'Footprint_Graze': 0.06,
#   'Footprint_Forest': 0.52,
#   'Footprint_Carbon': 3.01,
#   'Footprint_Fish': 0.14,
#   'Footprint_Total': 4.25,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 44,
#   'BioCap': 89.33,
#   'BioCap_RD': 85,
#   'Data_Quality': 3},
#  {'Country': 'Swaziland',
#   'HDI': 0.53,
#   'Footprint_Crop': 0.35,
#   'Footprint_Graze': 0.41,
#   'Footprint_Forest': 0.52,
#   'Footprint_Carbon': 0.67,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 2.01,
#   'Land_Urban': 0.06,
#   'Emission_CO2': 39,
#   'BioCap': 0.88,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Sweden',
#   'HDI': 0.9,
#   'Footprint_Crop': 1.47,
#   'Footprint_Graze': 0.27,
#   'Footprint_Forest': 1.3,
#   'Footprint_Carbon': 3.88,
#   'Footprint_Fish': 0.09,
#   'Footprint_Total': 7.25,
#   'Land_Urban': 0.24,
#   'Emission_CO2': 1428,
#   'BioCap': 10.62,
#   'BioCap_RD': 3,
#   'Data_Quality': 5},
#  {'Country': 'Switzerland',
#   'HDI': 0.93,
#   'Footprint_Crop': 0.75,
#   'Footprint_Graze': 0.22,
#   'Footprint_Forest': 0.38,
#   'Footprint_Carbon': 4.26,
#   'Footprint_Fish': 0.07,
#   'Footprint_Total': 5.79,
#   'Land_Urban': 0.12,
#   'Emission_CO2': 552,
#   'BioCap': 1.3,
#   'BioCap_RD': -4,
#   'Data_Quality': 6},
#  {'Country': 'Syrian Arab Republic',
#   'HDI': 0.62,
#   'Footprint_Crop': 0.52,
#   'Footprint_Graze': 0.09,
#   'Footprint_Forest': 0.04,
#   'Footprint_Carbon': 0.81,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.51,
#   'Land_Urban': 0.05,
#   'Emission_CO2': 237,
#   'BioCap': 0.6,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Tajikistan',
#   'HDI': 0.62,
#   'Footprint_Crop': 0.46,
#   'Footprint_Graze': 0.14,
#   'Footprint_Forest': 0.1,
#   'Footprint_Carbon': 0.13,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 0.91,
#   'Land_Urban': 0.08,
#   'Emission_CO2': 76,
#   'BioCap': 0.53,
#   'BioCap_RD': 0,
#   'Data_Quality': 5},
#  {'Country': 'Thailand',
#   'HDI': 0.72,
#   'Footprint_Crop': 0.67,
#   'Footprint_Graze': 0.02,
#   'Footprint_Forest': 0.24,
#   'Footprint_Carbon': 1.54,
#   'Footprint_Fish': 0.13,
#   'Footprint_Total': 2.66,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 3338,
#   'BioCap': 1.24,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Timor-Leste',
#   'HDI': 0.6,
#   'Footprint_Crop': 0.25,
#   'Footprint_Graze': 0.07,
#   'Footprint_Forest': 0.04,
#   'Footprint_Carbon': 0.06,
#   'Footprint_Fish': 0.02,
#   'Footprint_Total': 0.48,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 143,
#   'BioCap': 1.78,
#   'BioCap_RD': 1,
#   'Data_Quality': 3},
#  {'Country': 'Togo',
#   'HDI': 0.47,
#   'Footprint_Crop': 0.34,
#   'Footprint_Graze': 0.1,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 0.31,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 1.13,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 111,
#   'BioCap': 0.53,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Tonga',
#   'HDI': 0.72,
#   'Footprint_Crop': 1.19,
#   'Footprint_Graze': 0.32,
#   'Footprint_Forest': 0.14,
#   'Footprint_Carbon': 0.88,
#   'Footprint_Fish': 0.18,
#   'Footprint_Total': 2.7,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 0,
#   'BioCap': 1.48,
#   'BioCap_RD': -1,
#   'Data_Quality': 3},
#  {'Country': 'Trinidad and Tobago',
#   'HDI': 0.77,
#   'Footprint_Crop': 0.46,
#   'Footprint_Graze': 0.19,
#   'Footprint_Forest': 0.27,
#   'Footprint_Carbon': 6.89,
#   'Footprint_Fish': 0.11,
#   'Footprint_Total': 7.92,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 1663,
#   'BioCap': 1.56,
#   'BioCap_RD': -6,
#   'Data_Quality': 3},
#  {'Country': 'Tunisia',
#   'HDI': 0.72,
#   'Footprint_Crop': 0.76,
#   'Footprint_Graze': 0.09,
#   'Footprint_Forest': 0.28,
#   'Footprint_Carbon': 1.11,
#   'Footprint_Fish': 0.06,
#   'Footprint_Total': 2.34,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 274,
#   'BioCap': 0.93,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Turkey',
#   'HDI': 0.76,
#   'Footprint_Crop': 0.87,
#   'Footprint_Graze': 0.12,
#   'Footprint_Forest': 0.34,
#   'Footprint_Carbon': 1.92,
#   'Footprint_Fish': 0.04,
#   'Footprint_Total': 3.33,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 1303,
#   'BioCap': 1.52,
#   'BioCap_RD': -2,
#   'Data_Quality': 5},
#  {'Country': 'Turkmenistan',
#   'HDI': 0.68,
#   'Footprint_Crop': 0.73,
#   'Footprint_Graze': 0.44,
#   'Footprint_Forest': 0.08,
#   'Footprint_Carbon': 4.13,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 5.47,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 3270,
#   'BioCap': 2.79,
#   'BioCap_RD': -3,
#   'Data_Quality': 6},
#  {'Country': 'Uganda',
#   'HDI': 0.48,
#   'Footprint_Crop': 0.34,
#   'Footprint_Graze': 0.15,
#   'Footprint_Forest': 0.54,
#   'Footprint_Carbon': 0.08,
#   'Footprint_Fish': 0.11,
#   'Footprint_Total': 1.24,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 409,
#   'BioCap': 0.59,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Ukraine',
#   'HDI': 0.74,
#   'Footprint_Crop': 0.62,
#   'Footprint_Graze': 0.01,
#   'Footprint_Forest': 0.16,
#   'Footprint_Carbon': 1.92,
#   'Footprint_Fish': 0.06,
#   'Footprint_Total': 2.84,
#   'Land_Urban': 0.07,
#   'Emission_CO2': 3203,
#   'BioCap': 2.27,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'United Kingdom',
#   'HDI': 0.9,
#   'Footprint_Crop': 0.82,
#   'Footprint_Graze': 0.28,
#   'Footprint_Forest': 0.45,
#   'Footprint_Carbon': 3.14,
#   'Footprint_Fish': 0.08,
#   'Footprint_Total': 4.94,
#   'Land_Urban': 0.18,
#   'Emission_CO2': 4482,
#   'BioCap': 1.32,
#   'BioCap_RD': -4,
#   'Data_Quality': 6},
#  {'Country': 'United Arab Emirates',
#   'HDI': 0.83,
#   'Footprint_Crop': 0.8,
#   'Footprint_Graze': 0.19,
#   'Footprint_Forest': 0.38,
#   'Footprint_Carbon': 6.37,
#   'Footprint_Fish': 0.19,
#   'Footprint_Total': 7.93,
#   'Land_Urban': 0.0,
#   'Emission_CO2': 8642,
#   'BioCap': 0.56,
#   'BioCap_RD': -7,
#   'Data_Quality': 6},
#  {'Country': 'United States of America',
#   'HDI': 0.91,
#   'Footprint_Crop': 1.13,
#   'Footprint_Graze': 0.3,
#   'Footprint_Forest': 0.67,
#   'Footprint_Carbon': 5.9,
#   'Footprint_Fish': 0.12,
#   'Footprint_Total': 8.22,
#   'Land_Urban': 0.09,
#   'Emission_CO2': 83887,
#   'BioCap': 3.76,
#   'BioCap_RD': -4,
#   'Data_Quality': 6},
#  {'Country': 'Uruguay',
#   'HDI': 0.79,
#   'Footprint_Crop': 0.19,
#   'Footprint_Graze': 0.98,
#   'Footprint_Forest': 0.55,
#   'Footprint_Carbon': 0.98,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 2.91,
#   'Land_Urban': 0.17,
#   'Emission_CO2': 113,
#   'BioCap': 10.32,
#   'BioCap_RD': 7,
#   'Data_Quality': 3},
#  {'Country': 'Uzbekistan',
#   'HDI': 0.67,
#   'Footprint_Crop': 0.62,
#   'Footprint_Graze': 0.13,
#   'Footprint_Forest': 0.08,
#   'Footprint_Carbon': 1.41,
#   'Footprint_Fish': 0.0,
#   'Footprint_Total': 2.32,
#   'Land_Urban': 0.08,
#   'Emission_CO2': 2339,
#   'BioCap': 0.92,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Viet Nam',
#   'HDI': 0.66,
#   'Footprint_Crop': 0.5,
#   'Footprint_Graze': 0.01,
#   'Footprint_Forest': 0.19,
#   'Footprint_Carbon': 0.79,
#   'Footprint_Fish': 0.05,
#   'Footprint_Total': 1.65,
#   'Land_Urban': 0.1,
#   'Emission_CO2': 2977,
#   'BioCap': 1.0,
#   'BioCap_RD': -1,
#   'Data_Quality': 6},
#  {'Country': 'Yemen',
#   'HDI': 0.5,
#   'Footprint_Crop': 0.34,
#   'Footprint_Graze': 0.14,
#   'Footprint_Forest': 0.04,
#   'Footprint_Carbon': 0.42,
#   'Footprint_Fish': 0.04,
#   'Footprint_Total': 1.03,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 668,
#   'BioCap': 0.5,
#   'BioCap_RD': -1,
#   'Data_Quality': 5},
#  {'Country': 'Zambia',
#   'HDI': 0.58,
#   'Footprint_Crop': 0.19,
#   'Footprint_Graze': 0.18,
#   'Footprint_Forest': 0.33,
#   'Footprint_Carbon': 0.24,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 0.99,
#   'Land_Urban': 0.04,
#   'Emission_CO2': 374,
#   'BioCap': 2.23,
#   'BioCap_RD': 1,
#   'Data_Quality': 6},
#  {'Country': 'Zimbabwe',
#   'HDI': 0.49,
#   'Footprint_Crop': 0.2,
#   'Footprint_Graze': 0.32,
#   'Footprint_Forest': 0.29,
#   'Footprint_Carbon': 0.53,
#   'Footprint_Fish': 0.01,
#   'Footprint_Total': 1.37,
#   'Land_Urban': 0.02,
#   'Emission_CO2': 482,
#   'BioCap': 0.62,
#   'BioCap_RD': -1,
#   'Data_Quality': 6}]

# %%
CData = session.query(CountryData).all()

i = 0

for x in CData:
        
    fullCData = {}
    
    fullCData = {
        "Area": x.Surface_Area,
        "Population":x.Population,
        "PopDensity":x.PopDensity,
        "PopGrowth":x.PopGrowth,
        "PopUrban":x.PopUrban,
        "EconAg":x.EconAg,
        "EconInd":x.EconInd,
        "EconServ":x.EconService,
        "GovEducation":x.Gov_Education,
        "Women_Parliment":x.Women_Parliment
    }
        
    myData[i].update(fullCData)
    i = i+1

# %%
myData[0]['Country']
# Out:
# 'Afghanistan'

# %%
EmData = session.query(EmissionsData).all()


countrylist = []
yearlist=[]
emlist=[]

for x in EmData:
    countrylist.append(x.Country)
    yearlist.append(x.Year)
    emlist.append(x.Emissions)

# %%
for x in range(len(myData)):
    newyear=[]
    newem=[]
    for i in range(len(countrylist)):
        if countrylist[i]==myData[x]['Country']:
            newyear.append(yearlist[i])
            newem.append(emlist[i])
    myData[x].update({
        "Year":newyear,
        "Emissions":newem
    })

# %%
myData[1]
# Out:
# {'Country': 'Albania',
#  'HDI': 0.73,
#  'Footprint_Crop': 0.78,
#  'Footprint_Graze': 0.22,
#  'Footprint_Forest': 0.25,
#  'Footprint_Carbon': 0.87,
#  'Footprint_Fish': 0.02,
#  'Footprint_Total': 2.21,
#  'Land_Urban': 0.06,
#  'Emission_CO2': 84,
#  'BioCap': 1.18,
#  'BioCap_RD': -1,
#  'Data_Quality': 6,
#  'Area': 28748,
#  'Population': 2930,
#  'PopDensity': 106.9,
#  'PopGrowth': -0.1,
#  'PopUrban': 57.4,
#  'EconAg': 22.4,
#  'EconInd': 26.0,
#  'EconServ': 40.3,
#  'GovEducation': 3.5,
#  'Women_Parliment': 22.9,
#  'Year': [2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016],
#  'Emissions': [0.978174681,
#   1.053304176,
#   1.229540709,
#   1.412697196,
#   1.376212735,
#   1.412498211,
#   1.302576367,
#   1.322334855,
#   1.484311139,
#   1.495600199,
#   1.578573584,
#   1.803714725,
#   1.6979655569999998,
#   1.697279396,
#   1.90006971,
#   1.602648034,
#   1.577162624]}
